# %%
import pandas as pd

# %%
df = pd.read_json("myfile.json")

df.describe()
# Out:
#        CustomerID
# count   24.000000
# mean     2.000000
# std      0.834058
# min      1.000000
# 25%      1.000000
# 50%      2.000000
# 75%      3.000000
# max      3.000000

# %%
df.head(10)
# Out:
#    CustomerID     Name                Email
# 0           1    Alice    alice@example.com
# 1           2      Bob      bob@example.com
# 2           3  Charlie  charlie@example.com
# 3           1    Alice    alice@example.com
# 4           2      Bob      bob@example.com
# 5           3  Charlie  charlie@example.com
# 6           1    Alice    alice@example.com
# 7           2      Bob      bob@example.com
# 8           3  Charlie  charlie@example.com
# 9           1    Alice    alice@example.com

# %%
df = df.fillna(0)

# %%
df.iloc[0]
# Out:
# CustomerID                    1
# Name                      Alice
# Email         alice@example.com
# Name: 0, dtype: object

# %%
df1 = pd.read_xml("emp.xml")
df1
# Out:
#       id            Name           Description  Status
# 0  OP001    StartService    Starts the service  Active
# 1  OP002     StopService     Stops the service  Active
# 2  OP003  RestartService  Restarts the service  Active

# %%
import pandas as pd
df2 = pd.read_parquet("sample-users.parquet")
df2.describe()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df2 = pd.read_parquet("sample-users.parquet")
#       3 df2.describe()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parquet.py:653, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     500 @doc(storage_options=_shared_docs["storage_options"])
#     501 def read_parquet(
#     502     path: FilePath | ReadBuffer[bytes],
#    (...)
#     510     **kwargs,
#     511 ) -> DataFrame:
#     512     """
#     513     Load a parquet object from the file path, returning a DataFrame.
#     514
#    (...)
#     650     1    4    9
#     651     """
# --> 653     impl = get_engine(engine)
#     655     if use_nullable_dtypes is not lib.no_default:
#     656         msg = (
# ...

# %%
# %pip install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 26.2.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
df2 = pd.read_parquet("sample-users.parquet")
df2.describe()
# Out:
#            user_id          age      balance                 signup_date
# count  1000.000000  1000.000000  1000.000000                        1000
# mean    500.500000    46.672000  5082.639590  2022-10-23 10:45:07.200000
# min       1.000000    18.000000    34.730000         2020-01-01 00:00:00
# 25%     250.750000    32.000000  2742.807500         2021-06-03 06:00:00
# 50%     500.500000    47.000000  5097.490000         2022-12-07 00:00:00
# 75%     750.250000    61.000000  7534.075000         2024-02-14 12:00:00
# max    1000.000000    75.000000  9995.950000         2025-06-22 00:00:00
# std     288.819436    16.946374  2859.475186                         NaN

# %%
df4 = pd.read_orc("orc_test1_sample.orc")
df4
# Out:
#    boolean1  byte1  short1   int1                long1  float1  double1  \
# 0     False      1    1024  65536  9223372036854775807     1.0    -15.0
# 1      True    100    2048  65536  9223372036854775807     2.0     -5.0
#
#                     bytes1 string1  \
# 0  b'\x00\x01\x02\x03\x04'      hi
# 1                      b''     bye
#
#                                               middle  \
# 0  {'list': [{'int1': 1, 'string1': 'bye'}, {'int...
# 1  {'list': [{'int1': 1, 'string1': 'bye'}, {'int...
#
#                                                 list  \
# 0  [{'int1': 3, 'string1': 'good'}, {'int1': 4, '...
# 1  [{'int1': 100000000, 'string1': 'cat'}, {'int1...
#
#                                                  map
# 0                                                 []
# 1  [(chani, {'int1': 5, 'string1': 'chani'}), (ma...

# %%
df6 = pd.read_html("index.html")
df6
# Out:
# [    Employee ID Employee Name Department Designation  Salary
#  0          1001    Employee 1         IT    Engineer   51000
#  1          1002    Employee 2         HR     Analyst   52000
#  2          1003    Employee 3    Finance     Manager   53000
#  3          1004    Employee 4      Sales        Lead   54000
#  4          1005    Employee 5  Marketing   Executive   55000
#  ..          ...           ...        ...         ...     ...
#  95         1096   Employee 96         IT    Engineer  146000
#  96         1097   Employee 97         HR     Analyst  147000
#  97         1098   Employee 98    Finance     Manager  148000
#  98         1099   Employee 99      Sales        Lead  149000
#  99         1100  Employee 100  Marketing   Executive  150000
#
#  [100 rows x 5 columns]]

# %%
import pandas as pd
empdf = pd.read_excel("employees.xlsx")

empdf.dtypes
# Out:
# First Name                   object
# Gender                       object
# Start Date           datetime64[ns]
# Last Login Time              object
# Salary                        int64
# Bonus %                     float64
# Senior Management           float64
# Team                         object
# dtype: object

# %%
import pandas as pd

shipDf = pd.read_csv("dirty_data_ship.csv")

shipDf.dtypes
shipDf.head(10)
# Out:
#          Order ID  consumer_first_class  consumer_same_day  \
# 0  CA-2011-100293                   NaN                NaN
# 1  CA-2011-100706                   NaN                NaN
# 2  CA-2011-100895                   NaN                NaN
# 3  CA-2011-100916                   NaN                NaN
# 4  CA-2011-101266                   NaN                NaN
# 5  CA-2011-101560                   NaN                NaN
# 6  CA-2011-101770                   NaN                NaN
# 7  CA-2011-102274                   NaN                NaN
# 8  CA-2011-102673                   NaN                NaN
# 9  CA-2011-102988                   NaN                NaN
#
#    consumer_second_class  consumer_standard_class  consumer_total  \
# 0                    NaN                      NaN             NaN
# 1                 129.44                      NaN          129.44
# 2                    NaN                   605.47          605.47
# ...

# %%
print(shipDf.shape)
print(shipDf.info())
print(shipDf.isna().sum())
# Out:
# (823, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Order ID                    823 non-null    object
#  1   consumer_first_class        73 non-null     float64
#  2   consumer_same_day           29 non-null     float64
#  3   consumer_second_class       92 non-null     float64
#  4   consumer_standard_class     254 non-null    float64
#  5   consumer_total              445 non-null    float64
#  6   corporate_first_class       41 non-null     float64
#  7   corporate_same_day          6 non-null      float64
#  8   corporate_second_class      51 non-null     float64
#  9   corporate_standard_class    153 non-null    float64
#  10  corporate_total             248 non-null    float64
#  11  home_office_first_class     13 non-null     float64
# ...

# %%
import pandas as pd
df = pd.read_csv("dirty_data_ship.csv")
df.columns
s1 = df.melt(id_vars=['Order ID'],var_name='Segment',value_name='Sales')
s1
# Out:
#              Order ID               Segment       Sales
# 0      CA-2011-100293  consumer_first_class         NaN
# 1      CA-2011-100706  consumer_first_class         NaN
# 2      CA-2011-100895  consumer_first_class         NaN
# 3      CA-2011-100916  consumer_first_class         NaN
# 4      CA-2011-101266  consumer_first_class         NaN
# ...               ...                   ...         ...
# 12340  US-2014-166611     home_office_total         NaN
# 12341  US-2014-167920     home_office_total         NaN
# 12342  US-2014-168116     home_office_total         NaN
# 12343  US-2014-168690     home_office_total         NaN
# 12344     Grand Total     home_office_total  74255.0015
#
# [12345 rows x 3 columns]

# %%
s1 = s1.dropna(subset=["Sales"])
s1
# Out:
#              Order ID               Segment       Sales
# 11     CA-2011-103366  consumer_first_class    149.9500
# 20     CA-2011-109043  consumer_first_class    243.6000
# 29     CA-2011-113166  consumer_first_class      9.5680
# 51     CA-2011-124023  consumer_first_class      8.9600
# 63     CA-2011-130155  consumer_first_class     34.2000
# ...               ...                   ...         ...
# 12324  US-2014-148768     home_office_total     71.9760
# 12331  US-2014-156083     home_office_total      9.6640
# 12333  US-2014-159205     home_office_total    732.9300
# 12335  US-2014-162558     home_office_total   2437.6720
# 12344     Grand Total     home_office_total  74255.0015
#
# [1659 rows x 3 columns]

# %%
s1['Segment'] = (
    s1['Segment']
    .str.replace('_', ' ')
    .str.title()
)
s1
# Out:
# C:\Users\Y856864\AppData\Local\Temp\ipykernel_36880\712646529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s1['Segment'] = (
#              Order ID               Segment       Sales
# 11     CA-2011-103366  Consumer First Class    149.9500
# 20     CA-2011-109043  Consumer First Class    243.6000
# 29     CA-2011-113166  Consumer First Class      9.5680
# 51     CA-2011-124023  Consumer First Class      8.9600
# 63     CA-2011-130155  Consumer First Class     34.2000
# ...               ...                   ...         ...
# 12324  US-2014-148768     Home Office Total     71.9760
# 12331  US-2014-156083     Home Office Total      9.6640
# 12333  US-2014-159205     Home Office Total    732.9300
# ...

# %%
s1 = s1.rename(
    columns={
        'Order ID':'OrderID'
    }
)
print(s1.head(20))
# s1.to_csv("Clean_Ship_data.csv" , index = False)
# Out:
#             OrderID               Segment     Sales
# 11   CA-2011-103366  Consumer First Class   149.950
# 20   CA-2011-109043  Consumer First Class   243.600
# 29   CA-2011-113166  Consumer First Class     9.568
# 51   CA-2011-124023  Consumer First Class     8.960
# 63   CA-2011-130155  Consumer First Class    34.200
# 76   CA-2011-136861  Consumer First Class    31.984
# 104  CA-2011-153927  Consumer First Class   286.650
# 113  CA-2011-157784  Consumer First Class   514.030
# 119  CA-2011-160094  Consumer First Class  1000.950
# 128  CA-2011-164749  Consumer First Class     9.912
# 134  CA-2011-166730  Consumer First Class    39.128
# 146  CA-2012-102722  Consumer First Class   106.500
# 147  CA-2012-102778  Consumer First Class    18.176
# 179  CA-2012-117828  Consumer First Class   194.320
# 204  CA-2012-130218  Consumer First Class    59.480
# 206  CA-2012-132318  Consumer First Class   182.910
# 220  CA-2012-137974  Consumer First Class  2298.900
# ...

# %%
# s1[['Segment', 'Ship Mode']] = s1['Segment'].str.split(' ', n=1, expand=True)

# # Rearrange columns if you want Ship Mode right after Segment
# s1 = s1[['OrderID', 'Segment', 'Ship Mode', 'Sales']]

# s1
# Force the split result to have exactly 2 columns
split_df = s1['Segment'].str.split(' ', n=1, expand=True).reindex(columns=[0, 1])
# print(split_df)
# Assign safely
s1['Segment'] = split_df[0]
s1['Ship Mode'] = split_df[1]

s1
# Out:
#               OrderID   Segment       Sales     Ship Mode
# 11     CA-2011-103366  Consumer    149.9500   First Class
# 20     CA-2011-109043  Consumer    243.6000   First Class
# 29     CA-2011-113166  Consumer      9.5680   First Class
# 51     CA-2011-124023  Consumer      8.9600   First Class
# 63     CA-2011-130155  Consumer     34.2000   First Class
# ...               ...       ...         ...           ...
# 12324  US-2014-148768      Home     71.9760  Office Total
# 12331  US-2014-156083      Home      9.6640  Office Total
# 12333  US-2014-159205      Home    732.9300  Office Total
# 12335  US-2014-162558      Home   2437.6720  Office Total
# 12344     Grand Total      Home  74255.0015  Office Total
#
# [1659 rows x 4 columns]
